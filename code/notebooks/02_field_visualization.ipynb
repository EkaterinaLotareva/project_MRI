# %%
from ipywidgets import interact, FloatSlider

@interact(omega_MHz=FloatSlider(min=40, max=80, step=0.5, value=58.5))
def plot_field_interactive(omega_MHz):
    omega = 2*np.pi*omega_MHz*1e6
    plot_field_contour(X, Y, B_magnitude, title=f"ω = {omega_MHz} МГц")
