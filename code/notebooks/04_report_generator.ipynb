# %%
# Ячейка с финальными результатами
print(f"## Результаты расчёта")
print(f"- Частота: {frequency_MHz} МГц")
print(f"- Макс. поле в центре: {B_center_max:.3e} Тл")
print(f"- Неоднородность: {uniformity*100:.2f}%")

# Вставка графиков
from IPython.display import Image
Image('B_field_stationary.png')
Image('resonance_curve.png')
