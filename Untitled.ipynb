# %%
print("TEST: Kernel is alive!")
2 + 2
# Out:
# TEST: Kernel is alive!
# 4

# %%
# Тест импорта из твоей библиотеки
import sys
import os

# Добавляем корень проекта в путь поиска
sys.path.insert(0, os.path.abspath('..'))

print("Путь к проекту:", os.path.abspath('..'))
print("Содержимое src/:", os.listdir('src'))

# Пробуем импортировать
try:
    from src.geometry import points_on_rings_general
    print("✅ Импорт geometry успешен!")
except Exception as e:
    print(f"❌ Ошибка импорта geometry: {e}")

try:
    from src.currents import Z_self_matrix
    print("✅ Импорт currents успешен!")
except Exception as e:
    print(f"❌ Ошибка импорта currents: {e}")
# Out:
# Путь к проекту: C:\
# Содержимое src/: ['currents.py', 'geometry.py', 'inductance.py', 'magnetic_field.py', 'optimization.py', 'visualization.py']
# ✅ Импорт geometry успешен!
# ✅ Импорт currents успешен!
